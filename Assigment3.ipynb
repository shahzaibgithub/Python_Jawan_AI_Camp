# %%
#Task 1
#Simple Calculator

print("Shahzaib Ali")
print("Assigment 3")

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Select operation:")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")
print("5. Power")

choice = input("Enter choice (1/2/3/4/5): ")

if choice == '1':
    print("Result:", num1 + num2)

elif choice == '2':
    print("Result:", num1 - num2)

elif choice == '3':
    print("Result:", num1 * num2)

elif choice == '4':
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Cannot divide by zero")

elif choice == '5':
    print("Result:", num1 ** num2)

else:
    print("Invalid choice")
# Out:
# Shahzaib Ali
# Assigment 3
# Enter first number:  8
# Enter second number:  9
# Select operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Power
# Enter choice (1/2/3/4/5):  1
# Result: 17.0

# %%
#Task 2
#Numeric value in list usin loop

my_list = ["Shahzaib", "Ali", 25, "Jamshoro"]

found = False

for item in my_list:
    if isinstance(item, (int, float)):
        found = True
        break

if found:
    print("Numeric value exists in the list.")
else:
    print("No numeric value found.")
# Out:
# No numeric value found.

# %%
#Task 3
#Add key to a dictoniary
my_dict = {"name": "Shahzaib", "age": 23}

# Adding new key
my_dict["Qualification"] = "Graduation"

print(my_dict)
# Out:
# {'name': 'Shahzaib', 'age': 23, 'Qualification': 'Graduation'}

# %%
#Task 4
#Numeric item in Dictoniary
my_dict = {"a": 10, "b": 20, "c": 5}

total = 0

for value in my_dict.values():
    if isinstance(value, (int, float)):
        total += value

print("Sum of numeric values:", total)
# Out:
# Sum of numeric values: 35

# %%
#Task 5
#Identify duplicate values from list

my_list = [1, 2, 3, 2, 4, 5, 1]

duplicates = []

for item in my_list:
    if my_list.count(item) > 1 and item not in duplicates:
        duplicates.append(item)

print("Duplicate values:", duplicates)
# Out:
# Duplicate values: [1, 2]

# %%
#Task 6
#Check if a given key exists in dictionary
my_dict = {"name": "Ali", "age": 22}

key = input("Enter key to check: ")

if key in my_dict:
    print("Key exists in dictionary.")
else:
    print("Key does not exist.")
# Out:
# Enter key to check:  22
# Key does not exist.
